# %% [markdown]
# # 1. Y ~ X (Linear Regression) and Z_j ~ X (Linear Regression/Logistic Regression)

# %% [markdown]
# ```raw
#                                     r2_mean     rmse_mean  log_loss_mean
# target              type
# Age                 regression      -0.1653  4.455000e+00            NaN
# Capacity            regression      -0.1275  1.128938e+03            NaN
# DRAFT_NUMBER        regression       0.0543  1.547820e+01            NaN
# Followers           regression      -0.0583  2.506643e+06            NaN
# OWNER_NET_WORTH_B   regression      -0.4183  2.643790e+01            NaN
# STADIUM_COST        regression      -0.1446  4.561890e+08            NaN
# STADIUM_YEAR_OPENED regression      -0.2180  1.332410e+01            NaN
# Salary_Model        regression       0.3964  1.042100e+00            NaN
# active_cap          regression      -0.0240  1.618674e+07            NaN
# dead_cap            regression      -0.3559  9.286072e+06            NaN
# is_USA              classification      NaN           NaN         0.6648
#   - Estimating Gamma Coefficients (OLS on DML Residuals)...
# Running final OLS regression on residuals...
# Final OLS regression complete.
#
# --- Learned Market Prices (Gamma & Significance) ---
#                      Gamma (Price)  P-Value  Std. Error
# Age                        0.04873  0.03116     0.02261
# DRAFT_NUMBER              -0.01064  0.03959     0.00517
# dead_cap                   0.00000  0.11284     0.00000
# is_USA                    -0.25354  0.14612     0.17445
# const                      0.06113  0.37414     0.06878
# STADIUM_COST              -0.00000  0.41856     0.00000
# Capacity                   0.00006  0.45934     0.00008
# OWNER_NET_WORTH_B         -0.00283  0.52367     0.00443
# active_cap                -0.00000  0.60871     0.00000
# STADIUM_YEAR_OPENED        0.00279  0.77779     0.00987
# Followers                 -0.00000  0.91115     0.00000
# ```

# %% [markdown]
# # 2. (Y ~ X) GradientBoostingRegressor, (Z_j ~ X) GradientBoostingRegressor, GradientBoostingClassifer

# %% [markdown]
# ```raw
#                                     r2_mean     rmse_mean  log_loss_mean
# target              type
# Age                 regression      -0.0912  4.316400e+00            NaN
# Capacity            regression      -0.2124  1.171425e+03            NaN
# DRAFT_NUMBER        regression       0.0766  1.535860e+01            NaN
# Followers           regression      -0.5678  2.952239e+06            NaN
# OWNER_NET_WORTH_B   regression      -0.8799  2.879270e+01            NaN
# STADIUM_COST        regression      -0.1514  4.497138e+08            NaN
# STADIUM_YEAR_OPENED regression      -0.0412  1.228670e+01            NaN
# Salary_Model        regression       0.3679  1.059400e+00            NaN
# active_cap          regression      -0.0649  1.638843e+07            NaN
# dead_cap            regression      -0.5946  1.018344e+07            NaN
# is_USA              classification      NaN           NaN         0.6619
#   - Estimating Gamma Coefficients (OLS on DML Residuals)...
# Running final OLS regression on residuals...
# Final OLS regression complete.
#
# --- Learned Market Prices (Gamma & Significance) ---
#                      Gamma (Price)  P-Value  Std. Error
# Age                        0.04984  0.02573     0.02235
# active_cap                -0.00000  0.08686     0.00000
# DRAFT_NUMBER              -0.00957  0.12052     0.00617
# STADIUM_YEAR_OPENED       -0.01137  0.30594     0.01111
# dead_cap                   0.00000  0.46072     0.00000
# const                      0.03253  0.66587     0.07533
# Followers                  0.00000  0.69566     0.00000
# STADIUM_COST               0.00000  0.91365     0.00000
# Capacity                  -0.00001  0.93646     0.00008
# OWNER_NET_WORTH_B          0.00028  0.94565     0.00409
# is_USA                    -0.00921  0.95105     0.15010
# ```

# %% [markdown]
# 0.43 -> 0.46 after adding "god" features lol

# %% [markdown]
# ```raw
# [Diagnostic] Checking Feature Importance (Gradient Boosting)...
#                  Feature  Importance
# 30            CLUTCH_PTS    0.325360
# 15                  POSS    0.160420
# 31             CLUTCH_GP    0.136993
# 16                FGM_PG    0.099433
# 0             OFF_RATING    0.093610
# 17                FGA_PG    0.036887
# 2             NET_RATING    0.033869
# 1             DEF_RATING    0.019417
# 13                   PIE    0.015152
# 3                AST_PCT    0.010483
# 18                    GP    0.010416
# 21             AVG_SPEED    0.010211
# 19                   MIN    0.009612
# 22            DIST_MILES    0.008038
# 28              POST_PTS    0.007477
# 14               USG_PCT    0.004193
# 10               EFG_PCT    0.003657
# 11                TS_PCT    0.003188
# 26               PNR_PTS    0.002540
# 23  ALL_STAR_APPEARANCES    0.001841
# 12                  PACE    0.001378
# 9             TM_TOV_PCT    0.001234
# 32           RIM_DFG_PCT    0.001109
# 29              POST_PPP    0.000914
# 7                REB_PCT    0.000660
# 24               ISO_PTS    0.000582
# 5              AST_RATIO    0.000448
# 25               ISO_PPP    0.000394
# 8               DREB_PCT    0.000253
# 4                 AST_TO    0.000232
# 6               OREB_PCT    0.000000
# 20                   PTS    0.000000
# 27               PNR_PPP    0.000000
# 33      RIM_CONTEST_FREQ    0.000000
# ```
